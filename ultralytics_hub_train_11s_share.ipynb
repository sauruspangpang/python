# %% [markdown]
# # 0. Installation

# %%
! pip install -U ultralytics

# %% [markdown]
# # 1. Colors Classification

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('put your API key here')

model = YOLO('https://hub.ultralytics.com/models/6oJvwuokqNp4dZDNb2Ps')
results = model.train()
# Out:
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# Setup complete  (32 CPUs, 31.6 GB RAM, 657.9/3725.1 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/6oJvwuokqNp4dZDNb2Ps
# ...
# 100%|██████████| 13.0M/13.0M [00:00<00:00, 32.9MB/s]
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# ...

# %% [markdown]
# # 2. Animals Detection

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('put your API key here')

model = YOLO('https://hub.ultralytics.com/models/G7JJ2z4nhB6UbCJYpogi')
results = model.train()
# Out:
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# Setup complete  (32 CPUs, 31.6 GB RAM, 661.6/3725.1 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/G7JJ2z4nhB6UbCJYpogi
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 56.6MB/s]
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# ...

# %% [markdown]
# # 3. Fruits Detection

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('put your API key here')

model = YOLO('https://hub.ultralytics.com/models/6Mm3LqA2Q2TBCLpV1bID')
results = model.train()
# Out:
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# Setup complete  (32 CPUs, 31.6 GB RAM, 658.4/3725.1 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/6Mm3LqA2Q2TBCLpV1bID
# Ultralytics 8.3.73  Python-3.10.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# ...
